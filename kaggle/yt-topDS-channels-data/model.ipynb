# %% [markdown]
# # EDA of Top DS and ML channels on YouTube

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("dark_background")
palette = sns.color_palette("husl", 8)

# %%
df = pd.read_csv("YT_ds_channels.csv")
df.head()
# Out:
#            youtuber               id  uploads subscribers  video views  \
# 0       3Blue1Brown     @3blue1brown      127       4.91M    316927667
# 1         Joma Tech        @jomaoppa      107       2.06M    164892515
# 2  The Coding Train  @thecodingtrain     1210       1.54M    110960063
# 3           sentdex         @sentdex     1233        1.2M    107212166
# 4     Tech With Tim     @techwithtim      772       1.14M    102224704
#
#   country account created estimated monthly income
# 0      US   Mar 3rd, 2015            $844 - $13.5K
# 1      US  Aug 31st, 2016            $711 - $11.4K
# 2      US   Jul 3rd, 2006             $229 - $3.7K
# 3      US  Dec 16th, 2012             $214 - $3.4K
# 4      CA  Apr 23rd, 2014             $516 - $8.3K

# %% [markdown]
# ## Data Description
#
#
# 1. youtuber – Name of the YouTube channel
# 2. id – Channel ID
# 3. uploads – number of videos uploaded on the channels
# 4. subscribers – of subscribers of the channel
# 5. video views – total count of all videos in the channel
# 6. country - the two-letter country abbreviation
# 7. account created – date of creation of the channel
# 8. estimated monthly income - This is the range of estimated monthly income based on CPM, or cost per mille, and shows how much advertisers pay

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   youtuber                  30 non-null     object
#  1   id                        30 non-null     object
#  2   uploads                   30 non-null     int64
#  3   subscribers               30 non-null     object
#  4   video views               30 non-null     int64
#  5   country                   30 non-null     object
#  6   account created           30 non-null     object
#  7   estimated monthly income  30 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 2.0+ KB

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Lets start with ***subscribers*** coloum

# %%
subs_arr = df["subscribers"]
new_subs = []
for i in range(len(subs_arr)):
    # print(subs_arr[i][-1])
    prefix = subs_arr[i][-1]
    sub_count = subs_arr[i][:-1]
    if prefix == "M":
        new_subs.append(float(sub_count) * 1000000)
    if prefix == "K":
        new_subs.append(float(sub_count) * 1000)        

df_copy = df.copy()
df_copy["subscribers"] = new_subs

# %% [markdown]
# ### Now, lets the ***year*** in the channel was created

# %%
yrs_arr = df["account created"]
new_yrs = []
for i in range(len(yrs_arr)):
    new_yrs.append(yrs_arr[i].split(" ", -1)[-1])
    # break

df_copy["year_created"] = new_yrs

# %% [markdown]
# ### Lets, get some ***min, max, avg. of the monthly income***

# %%
import re

income = df["estimated monthly income"]
min_income, max_income, avg_income = [],[],[]
for i in range(len(income)):
    
    min_val = float(re.findall(r'\d+', income[i])[0])
    min_income.append(min_val)
    
    inc1 = income[i].split("- ", 1)[-1]
    inc1 = inc1[1:]
    
    if inc1[-1] == "K":
        max_val = float(inc1[0:-1])*1000
        
    max_income.append(max_val)

    avg_income.append((min_val+max_val)/2)
df_copy["min_income"], df_copy["max_income"], df_copy["avg_income"] = min_income, max_income, avg_income

# %% [markdown]
# ### Rename and change the data type of the coloumns

# %%
df_copy = df_copy.rename(columns={"video views": "total_veiws"})

df_copy['subscribers'] = df_copy['subscribers'].astype(int)
df_copy['min_income'] = df_copy['min_income'].astype(int)
df_copy['max_income'] = df_copy['max_income'].astype(int)
df_copy['avg_income'] = df_copy['avg_income'].astype(int)

# %% [markdown]
# ### Drop the unnecessary coloumns

# %%
df_copy.drop(['account created', 'estimated monthly income'], axis=1, inplace=True)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   youtuber      30 non-null     object
#  1   id            30 non-null     object
#  2   uploads       30 non-null     int64
#  3   subscribers   30 non-null     int32
#  4   total_veiws   30 non-null     int64
#  5   country       30 non-null     object
#  6   year_created  30 non-null     object
#  7   min_income    30 non-null     int32
#  8   max_income    30 non-null     int32
#  9   avg_income    30 non-null     int32
# dtypes: int32(4), int64(2), object(4)
# memory usage: 2.0+ KB

# %%
df_copy.describe()
# Out:
#            uploads   subscribers   total_veiws  min_income    max_income  \
# count    30.000000  3.000000e+01  3.000000e+01   30.000000     30.000000
# mean    387.633333  5.923737e+05  4.099272e+07  158.866667   3800.000000
# std     403.531094  9.654415e+05  6.722583e+07  212.030696   2816.943807
# min      32.000000  6.150000e+03  2.521440e+05    0.000000   1600.000000
# 25%     137.500000  5.717500e+04  2.771000e+06   11.750000   1700.000000
# 50%     226.500000  2.515000e+05  1.110823e+07   77.500000   3500.000000
# 75%     427.500000  7.210000e+05  4.828713e+07  217.500000   4000.000000
# max    1600.000000  4.910000e+06  3.169277e+08  844.000000  13500.000000
#
#         avg_income
# count    30.000000
# mean   1979.233333
# std    1505.008436
# min     850.000000
# 25%     860.250000
# 50%    1858.500000
# 75%    2014.500000
# max    7172.000000

# %% [markdown]
# ## Data Visualization

# %%
df_copy.head()
# Out:
#            youtuber               id  uploads  subscribers  total_veiws  \
# 0       3Blue1Brown     @3blue1brown      127      4910000    316927667
# 1         Joma Tech        @jomaoppa      107      2060000    164892515
# 2  The Coding Train  @thecodingtrain     1210      1540000    110960063
# 3           sentdex         @sentdex     1233      1200000    107212166
# 4     Tech With Tim     @techwithtim      772      1140000    102224704
#
#   country year_created  min_income  max_income  avg_income
# 0      US         2015         844       13500        7172
# 1      US         2016         711       11400        6055
# 2      US         2006         229        3700        1964
# 3      US         2012         214        3400        1807
# 4      CA         2014         516        8300        4408

# %% [markdown]
# ### Youtube Channels of different countires

# %%
plt.figure(figsize=(20, 7))
countries = df_copy["country"].value_counts()

plt.subplot(1, 2, 1)
sns.barplot(data=df_copy, y=countries, x=df_copy["country"].unique(), palette=palette)
plt.xlabel('country')
plt.ylabel('channel count')

plt.subplot(1, 2, 2)

plt.pie(data=df_copy, x=countries, labels=df_copy["country"].unique(), autopct='%.0f%%', colors=palette, explode = [0.05,0,0,0,0,0,0])
plt.title("Different countries of Channels")


plt.show()

# %% [markdown]
# ### Growth of Channels

# %%
plt.figure(figsize=(20, 7))

year_count = df_copy.groupby(['year_created']).count()
year_count.iloc[:, 0].values

plt.plot(year_count.iloc[:, 0].index, year_count.iloc[:, 0].values, linestyle = 'dotted', marker="o", color='#e274d1', 
         markerfacecolor='#cdcdcd', markersize=9)
plt.xlabel('year')
plt.ylabel('count')
plt.title("Growth of Channels")

plt.show()

# %% [markdown]
# ### Subscribers count different of Channels

# %%
plt.figure(figsize=(15, 10))

sns.barplot(x=df_copy['subscribers'], y=df_copy['youtuber'], palette=palette)
plt.xlabel('count')
plt.ylabel('Yotubers')
plt.title("Subscribers count different of Channels")

plt.show()

# %% [markdown]
# ### Correlation

# %%
df_copy.corr().style.background_gradient(cmap=plt.cm.cubehelix)
# Out:
# <style type="text/css">
# #T_98580_row0_col0, #T_98580_row1_col1, #T_98580_row2_col2, #T_98580_row3_col3, #T_98580_row4_col4, #T_98580_row4_col5, #T_98580_row5_col4, #T_98580_row5_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_98580_row0_col1, #T_98580_row0_col2, #T_98580_row0_col3, #T_98580_row0_col4, #T_98580_row0_col5, #T_98580_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_98580_row1_col0 {
#   background-color: #050205;
#   color: #f1f1f1;
# }
# #T_98580_row1_col2 {
#   background-color: #f8fdfa;
#   color: #000000;
# }
# #T_98580_row1_col3 {
#   background-color: #c6e1f1;
#   color: #000000;
# }
# #T_98580_row1_col4 {
#   background-color: #c2d2f3;
#   color: #000000;
# }
# #T_98580_row1_col5, #T_98580_row5_col2 {
#   background-color: #c2d6f3;
#   color: #000000;
# }
# #T_98580_row2_col0 {
#   background-color: #1b1a36;
#   color: #f1f1f1;
# }
# #T_98580_row2_col1 {
#   background-color: #fafdfb;
#   color: #000000;
# }
# #T_98580_row2_col3 {
#   background-color: #cfebef;
#   color: #000000;
# }
# #T_98580_row2_col4 {
#   background-color: #c3daf2;
#   color: #000000;
# }
# #T_98580_row2_col5 {
#   background-color: #c4ddf2;
#   color: #000000;
# }
# #T_98580_row3_col0 {
#   background-color: #170e23;
#   color: #f1f1f1;
# }
# #T_98580_row3_col1 {
#   background-color: #c8e4f0;
#   color: #000000;
# }
# #T_98580_row3_col2, #T_98580_row4_col3 {
#   background-color: #cdeaef;
#   color: #000000;
# }
# #T_98580_row3_col4 {
#   background-color: #d0ecef;
#   color: #000000;
# }
# #T_98580_row3_col5 {
#   background-color: #d6f0ef;
#   color: #000000;
# }
# #T_98580_row4_col1, #T_98580_row4_col2 {
#   background-color: #c1d1f3;
#   color: #000000;
# }
# #T_98580_row5_col0 {
#   background-color: #020102;
#   color: #f1f1f1;
# }
# #T_98580_row5_col1 {
#   background-color: #c2d4f3;
#   color: #000000;
# }
# #T_98580_row5_col3 {
#   background-color: #d3eeef;
#   color: #000000;
# }
# </style>
# <table id="T_98580">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98580_level0_col0" class="col_heading level0 col0" >uploads</th>
#       <th id="T_98580_level0_col1" class="col_heading level0 col1" >subscribers</th>
#       <th id="T_98580_level0_col2" class="col_heading level0 col2" >total_veiws</th>
#       <th id="T_98580_level0_col3" class="col_heading level0 col3" >min_income</th>
#       <th id="T_98580_level0_col4" class="col_heading level0 col4" >max_income</th>
#       <th id="T_98580_level0_col5" class="col_heading level0 col5" >avg_income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98580_level0_row0" class="row_heading level0 row0" >uploads</th>
#       <td id="T_98580_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_98580_row0_col1" class="data row0 col1" >0.111308</td>
#       <td id="T_98580_row0_col2" class="data row0 col2" >0.204040</td>
#       <td id="T_98580_row0_col3" class="data row0 col3" >0.168940</td>
#       <td id="T_98580_row0_col4" class="data row0 col4" >0.098963</td>
#       <td id="T_98580_row0_col5" class="data row0 col5" >0.104524</td>
#     </tr>
#     <tr>
#       <th id="T_98580_level0_row1" class="row_heading level0 row1" >subscribers</th>
#       <td id="T_98580_row1_col0" class="data row1 col0" >0.111308</td>
#       <td id="T_98580_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_98580_row1_col2" class="data row1 col2" >0.986875</td>
#       <td id="T_98580_row1_col3" class="data row1 col3" >0.880599</td>
#       <td id="T_98580_row1_col4" class="data row1 col4" >0.835221</td>
#       <td id="T_98580_row1_col5" class="data row1 col5" >0.843696</td>
#     </tr>
#     <tr>
#       <th id="T_98580_level0_row2" class="row_heading level0 row2" >total_veiws</th>
#       <td id="T_98580_row2_col0" class="data row2 col0" >0.204040</td>
#       <td id="T_98580_row2_col1" class="data row2 col1" >0.986875</td>
#       <td id="T_98580_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_98580_row2_col3" class="data row2 col3" >0.907201</td>
#       <td id="T_98580_row2_col4" class="data row2 col4" >0.852246</td>
#       <td id="T_98580_row2_col5" class="data row2 col5" >0.861504</td>
#     </tr>
#     <tr>
#       <th id="T_98580_level0_row3" class="row_heading level0 row3" >min_income</th>
#       <td id="T_98580_row3_col0" class="data row3 col0" >0.168940</td>
#       <td id="T_98580_row3_col1" class="data row3 col1" >0.880599</td>
#       <td id="T_98580_row3_col2" class="data row3 col2" >0.907201</td>
#       <td id="T_98580_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_98580_row3_col4" class="data row3 col4" >0.904083</td>
#       <td id="T_98580_row3_col5" class="data row3 col5" >0.916558</td>
#     </tr>
#     <tr>
#       <th id="T_98580_level0_row4" class="row_heading level0 row4" >max_income</th>
#       <td id="T_98580_row4_col0" class="data row4 col0" >0.098963</td>
#       <td id="T_98580_row4_col1" class="data row4 col1" >0.835221</td>
#       <td id="T_98580_row4_col2" class="data row4 col2" >0.852246</td>
#       <td id="T_98580_row4_col3" class="data row4 col3" >0.904083</td>
#       <td id="T_98580_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_98580_row4_col5" class="data row4 col5" >0.999545</td>
#     </tr>
#     <tr>
#       <th id="T_98580_level0_row5" class="row_heading level0 row5" >avg_income</th>
#       <td id="T_98580_row5_col0" class="data row5 col0" >0.104524</td>
#       <td id="T_98580_row5_col1" class="data row5 col1" >0.843696</td>
#       <td id="T_98580_row5_col2" class="data row5 col2" >0.861504</td>
#       <td id="T_98580_row5_col3" class="data row5 col3" >0.916558</td>
#       <td id="T_98580_row5_col4" class="data row5 col4" >0.999545</td>
#       <td id="T_98580_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df_copy.corr(), annot = True, cmap=plt.cm.cubehelix_r, fmt='.3f', square=True)
plt.show()

# %% [markdown]
# ### Relationships between variables within a dataset by using the Pairplot

# %%
sns.pairplot(df_copy, hue='country', palette="PuOr_r")
plt.show()

# %% [markdown]
# ## Model

# %%
X, y = df_copy['total_veiws'].values, df_copy['avg_income'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
LReg = LinearRegression()

# %%
X_train, y_train = X_train.reshape(-1, 1), y_train
X_test, y_test = X_test.reshape(-1, 1), y_test

# %%
LReg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# array([ 850, 2008,  851, 2015,  851, 1859])

# %%
LReg.score(X_test, y_test)
# Out:
# -0.4692154073878463

# %%
LReg.predict(X_test)
# Out:
# array([1227.36036344, 1424.8737891 , 1263.39072937, 1361.54657153,
#        2120.46827314, 2076.00731753])

# %%
y_test
# Out:
# array([ 850, 2008,  851, 2015,  851, 1859])

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(X_test, y_test)
# Out:
# -0.46921540728219524
